# %% [markdown]
# <a href="https://colab.research.google.com/github/LibbyFender/StudentResources/blob/master/Viz_Refresh.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import sklearn as sk
import seaborn as sns
import numpy as np
import pandas as pd

from google.colab import drive
# Out:
# /usr/local/lib/python3.6/dist-packages/statsmodels/tools/_testing.py:19: FutureWarning: pandas.util.testing is deprecated. Use the functions in the public API at pandas.testing instead.
#   import pandas.util.testing as tm

# %%
# %load_ext rpy2.ipython
# Out:
# /usr/local/lib/python3.6/dist-packages/rpy2/robjects/pandas2ri.py:14: FutureWarning: pandas.core.index is deprecated and will be removed in a future version.  The public classes are available in the top-level namespace.
#   from pandas.core.index import Index as PandasIndex
# /usr/local/lib/python3.6/dist-packages/rpy2/robjects/pandas2ri.py:34: UserWarning: pandas >= 1.0 is not supported.
#   warnings.warn('pandas >= 1.0 is not supported.')

# %%
# %R require(ggplot2)
# Out:
# R[write to console]: Loading required package: ggplot2
# array([1], dtype=int32)

# %%
df = pd.DataFrame({'Letter':['a','a','a','b','b', 'b', 'c','c','c'],
                   'x': [4, 3,5,2,1,7,7,5,9],
                   'y': [0,4,3,6,7,10,11,9,13],
                   'z': [1,2,3,1,2,3,1,2,3]})

# %%
import matplotlib.pyplot as plt

# %%
# %%R -i df
# ggplot(data = df) + geom_point(aes(x = x, y= y, color = Letter, size = z))

# %%
df
# Out:
#   Letter  x   y  z
# 0      a  4   0  1
# 1      a  3   4  2
# 2      a  5   3  3
# 3      b  2   6  1
# 4      b  1   7  2
# 5      b  7  10  3
# 6      c  7  11  1
# 7      c  5   9  2
# 8      c  9  13  3

# %%
df.describe()
# Out:
#               x        y         z
# count  9.000000   9.0000  9.000000
# mean   4.777778   7.0000  2.000000
# std    2.587362   4.1833  0.866025
# min    1.000000   0.0000  1.000000
# 25%    3.000000   4.0000  1.000000
# 50%    5.000000   7.0000  2.000000
# 75%    7.000000  10.0000  3.000000
# max    9.000000  13.0000  3.000000

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9 entries, 0 to 8
# Data columns (total 4 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Letter  9 non-null      object
#  1   x       9 non-null      int64
#  2   y       9 non-null      int64
#  3   z       9 non-null      int64
# dtypes: int64(3), object(1)
# memory usage: 416.0+ bytes

# %%
sns.distplot(df['x'])

# %%
df['x'].value_counts().plot.bar()

# %%
sns.set_style("whitegrid")
sns.lmplot(x = 'x', y = 'z', data=df)

# %%
sns.violinplot(x='x', y='y', hue ='Letter', data = df)

# %%
sns.set_style("ticks")
sns.set_context('notebook')
sns.set_palette('husl')
sns.regplot(x="x", y="y", data=df)

# %%
#sns.FacetGrid(df, col='Letter', row='x')

# %%
# %matplotlib inline

# %%
fig = plt.figure()
ax = plt.axes(projection = '3d')

# %%
ax = plt.axes(projection = '3d')
ax.plot3D(xline, df['y'], df['z'], c='green')

# %%
ax = plt.axes(projection = '3d')
ax.scatter3D(xline, df['y'], df['z'], c='green')

# %%
ax = plt.axes(projection = '3d')
ax.scatter3D(xline, df['y'], df['z'], c='green')
ax.plot3D(xline, df['y'], df['z'], c='green')
